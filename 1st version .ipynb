# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu589/Satellite-EuroSAT/blob/main/1st%20version%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install patchify
# Out:
# Requirement already satisfied: patchify in /usr/local/lib/python3.11/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from patchify) (1.26.4)

# %%
import os
import cv2
import json
import numpy as np
import pandas as pd
import torch
import torchvision
import matplotlib.pyplot as plt
from PIL import Image
from patchify import patchify
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
from torchvision.io import read_image
import torchvision.transforms as T
import random
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                                    title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# atharvasoundankar/chocolate-sales                                      Chocolate Sales Data 📊🍫                                 14473  2025-03-19 03:51:40.270000           8852        144  1.0
# abdulmalik1518/mobiles-dataset-2025                                    Mobiles Dataset (2025)                                  20314  2025-02-18 06:50:24.370000          15193        268  1.0
# mahmoudelhemaly/students-grading-dataset                               Student Performance & Behavior Dataset                 520428  2025-02-17 17:38:46.653000          10896        172  1.0
# atharvasoundankar/global-water-consumption-dataset-2000-2024           Global Water Consumption Dataset (2000-2024) 🌍💧         17077  2025-03-17 04:50:38.880000           1954         33  1.0
# adilshamim8/student-depression-dataset                                 Student Depression Dataset                             467020  2025-03-13 03:12:30.423000           2071         38  1.0
# atharvasoundankar/global-food-wastage-dataset-2018-2024                🌍 Global Food Wastage Dataset (2018-2024) 🍽️           108611  2025-03-12 04:51:27.083000           1273         25  1.0
# parsabahramsari/wdi-education-health-and-employment-2011-2021          WDI: Education, Health & Employment (2011-2021)        136185  2025-03-07 08:29:38.617000            953         26  1.0
# muhammadtahir194/movies-dataset-tmdb-top-rated                         Movies Dataset TMDB (Top Rated)                       1198870  2025-03-15 07:04:08.817000           1002         22  0.7058824
# bhargavchirumamilla/netflix-movies-and-tv-shows-till-2025              Netflix Movies and TV shows till 2025                 6471169  2025-03-04 01:06:12.240000           1404         23  1.0
# smayanj/netflix-users-database                                         Netflix Users Database                                 362559  2025-03-08 12:08:09.403000           2052         49  1.0
# atharvasoundankar/global-energy-consumption-2000-2024                  Global Energy Consumption (2000-2024) 🔥⚡               258261  2025-03-14 05:06:39.413000           1544         32  1.0
# salahuddinahmedshuvo/ecommerce-consumer-behavior-analysis-data         Ecommerce Consumer Behavior Analysis Data               44265  2025-03-03 13:09:09.223000           3762         53  0.9411765
# aniruddhawankhede/mental-heath-analysis-among-teenagers                Mental_Heath_Analysis_Among_Teenagers                  177089  2025-03-10 12:17:22.827000           1795         34  1.0
# atharvasoundankar/global-music-streaming-trends-and-listener-insights  Global Music Streaming Trends & Listener Insights       97474  2025-03-09 05:12:00.547000           1659         28  1.0
# anandshaw2001/imdb-movies-and-tv-shows                                 IMDb Movies and TV Shows                              2548638  2025-02-22 05:57:52.997000           1468         36  1.0
# brsahan/genomic-data-for-cancer                                        Genomic Data for Cancer                                  9134  2025-03-16 08:44:59.287000            460         21  1.0
# atharvasoundankar/viral-social-media-trends-and-engagement-analysis    🚀 Viral Social Media Trends & Engagement Analysis      107245  2025-03-10 04:51:48.123000           2223         40  1.0
# amanrajput16/olympics-medal-list-1896-2024                             Olympic Medal List (1896-2024)                          11101  2025-03-11 09:41:29.323000            766         21  1.0
# adilshamim8/student-performance-on-an-entrance-examination             Student Performance on an Entrance Examination           4402  2025-03-04 00:09:21.697000           2127         45  1.0
# anandshaw2001/video-game-sales                                         Video Game Sales                                       390286  2025-02-23 05:16:04.587000           2196         67  1.0

# %%
# !kaggle datasets download -d apollo2506/eurosat-dataset -p data/ --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/apollo2506/eurosat-dataset
# License(s): CC0-1.0

# %%
# Set device (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Set directories
data_dir = "data/EuroSAT"

# %%
if os.path.exists(data_dir):
    classes = os.listdir(data_dir)
    print(f" Dataset contains {len(classes)} categories:")
    print(classes)
else:
    print(" Dataset extraction failed. Check the ZIP file.")
# Out:
#  Dataset contains 14 categories:
# ['test.csv', 'Pasture', 'validation.csv', 'PermanentCrop', 'HerbaceousVegetation', 'Forest', 'Residential', 'Highway', 'label_map.json', 'River', 'SeaLake', 'Industrial', 'train.csv', 'AnnualCrop']

# %%
# Define image size and number of classes
IMG_SIZE = (256, 256)
NUM_CLASSES = 10  # Update based on dataset

# %%
# Define color mapping for each class
land_classes = {
    "AnnualCrop": (255, 255, 0),     # Yellow
    "Forest": (0, 255, 0),           # Green
    "HerbaceousVegetation": (144, 238, 144),  # Light Green
    "Highway": (128, 128, 128),      # Gray
    "Industrial": (255, 0, 0),       # Red
    "Pasture": (139, 69, 19),        # Brown
    "PermanentCrop": (0, 128, 0),    # Dark Green
    "Residential": (255, 165, 0),    # Orange
    "River": (0, 0, 255),            # Blue
    "SeaLake": (0, 255, 255)         # Cyan
}

# %%
# Function to generate mask
def generate_mask(image):
    mask = np.zeros_like(image)

    for class_name, color in land_classes.items():
        # Define custom rules for land segmentation (example: color-based detection)
        if class_name == "Forest":
            lower, upper = np.array([0, 50, 0]), np.array([100, 255, 100])  # Detect green
        elif class_name == "Highway":
            lower, upper = np.array([100, 100, 100]), np.array([200, 200, 200])  # Detect gray
        elif class_name in ["River", "SeaLake"]:
            lower, upper = np.array([0, 0, 100]), np.array([100, 100, 255])  # Detect blue water
        else:
            continue  # Other classes require advanced methods

        # Create binary mask
        feature_mask = cv2.inRange(image, lower, upper)
        mask[feature_mask > 0] = color  # Apply color

    return mask

# %%
output_root = "masked_eurosat_images"
os.makedirs(output_root, exist_ok=True)


for path, subdirs, folders in os.walk(data_dir):
    dir_name = path.split(os.path.sep)[-1]
    print(f"Found directory: {dir_name}")

    output_dir = os.path.join(output_root, dir_name)
    os.makedirs(output_dir, exist_ok=True)

    images = os.listdir(path)
    for i, img_name in enumerate(images):
        if img_name.endswith(".jpg"):
            img_path = os.path.join(path, img_name)
            image = cv2.imread(img_path)
            if image is not None:  # Check if image was read successfully
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2078.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2974.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2616.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1635.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2393.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_154.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_813.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_514.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1377.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1411.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_78.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1384.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_853.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2972.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2861.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2148.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_49.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2492.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_448.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2044.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2990.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1370.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2016.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1632.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1307.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2863.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_842.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1317.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1325.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1211.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_675.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1376.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_925.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_605.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_790.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_283.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2560.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1389.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1296.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_533.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2051.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1414.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2076.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1771.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1509.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1918.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2055.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1650.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2792.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1812.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2090.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1467.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_973.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1591.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_890.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_361.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1600.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1003.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1671.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1582.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2521.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_497.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2436.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_402.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_800.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1961.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2676.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1724.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2375.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1672.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_19.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1625.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2743.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2963.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2627.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1482.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2391.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1718.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2453.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2336.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_590.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1071.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2058.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2693.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1750.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2757.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1327.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1886.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_859.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1089.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1759.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_767.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_32.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_584.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_558.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2767.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1109.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_572.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2438.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1897.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_199.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2197.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_81.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1840.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1369.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2698.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2557.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1755.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2274.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2350.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2157.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_876.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2416.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_617.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_593.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_961.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_713.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2272.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2854.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1932.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2089.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2800.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_138.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2422.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2951.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2483.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1047.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_791.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2501.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1624.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_109.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_309.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1949.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1501.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_946.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1593.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2095.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_208.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1416.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_834.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1709.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_296.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1046.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1252.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_701.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2655.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2135.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2458.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1361.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1182.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_763.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2821.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_525.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2314.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_12.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_886.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1659.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2701.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_210.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1989.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1103.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1631.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2524.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2885.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2084.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_960.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1680.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2572.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_235.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_577.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_14.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1012.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_99.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_511.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1434.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1402.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_175.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1151.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2667.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2791.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2499.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_738.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2261.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1806.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_1579.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2531.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_340.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2881.jpg
# Saved masked image: masked_eurosat_images/AnnualCrop/AnnualCrop_2060.jpg

# %%
train_csv = pd.read_csv("/content/data/EuroSAT/train.csv")
val_csv = pd.read_csv("/content/data/EuroSAT/validation.csv")
test_csv = pd.read_csv("/content/data/EuroSAT/test.csv")

# %%
def load_image_paths(csv_file, data_dir):
    image_paths = []
    labels = []

    for _, row in csv_file.iterrows():
        img_filename = row["Filename"].strip()  # Get full filename
        category = img_filename.split('/')[0]  # Extract category (e.g., "AnnualCrop")

        if category not in category_labels:
            print(f"Warning: Category '{category}' not found in labels.json")
            continue  # Skip files with missing labels

        img_path = os.path.join(data_dir, img_filename)  # Get image path
        image_paths.append(img_path)
        labels.append(category_labels[category])  # Get category label

    return image_paths, labels

# %%
from tensorflow.keras.utils import Sequence
import numpy as np

class DataGenerator(Sequence):
    def __init__(self, image_paths, labels, batch_size, img_size, num_classes, shuffle=True):
        self.image_paths = image_paths
        self.labels = labels
        self.batch_size = batch_size
        self.img_size = img_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, index):
        batch_image_paths = self.image_paths[index * self.batch_size:(index + 1) * self.batch_size]
        batch_labels = self.labels[index * self.batch_size:(index + 1) * self.batch_size]

        images = []
        labels = []
        for img_path, label in zip(batch_image_paths, batch_labels):
            # Load and preprocess image
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, self.img_size)
            img = img / 255.0  # Normalize

            # Convert label to one-hot encoding
            label = tf.keras.utils.to_categorical(label, num_classes=self.num_classes)

            images.append(img)
            labels.append(label)

        return np.array(images), np.array(labels)

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.image_paths))
            np.random.shuffle(indices)
            self.image_paths = [self.image_paths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# %%
# Load image paths and labels
train_image_paths, y_train = load_image_paths(train_csv, data_dir)
val_image_paths, y_val = load_image_paths(val_csv, data_dir)
test_image_paths, y_test = load_image_paths(test_csv, data_dir)

# %%
# Define parameters
batch_size = 16  # Adjust based on memory availability
img_size = (128, 128)  # Resize images to reduce memory usage
num_classes = 10  # Number of classes in EuroSAT

# Create data generators
train_generator = DataGenerator(train_image_paths, y_train, batch_size, img_size, num_classes)
val_generator = DataGenerator(val_image_paths, y_val, batch_size, img_size, num_classes)
test_generator = DataGenerator(test_image_paths, y_test, batch_size, img_size, num_classes)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam

# %%
def create_model(input_shape=(128, 128, 3), num_classes=10):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')  # Output layer for classification
    ])
    return model

# Create the model
model = create_model()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    validation_data=val_generator,
    validation_steps=len(val_generator),
    epochs=10
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 441s 370ms/step - accuracy: 0.3387 - loss: 1.7486 - val_accuracy: 0.5459 - val_loss: 1.2776
# Epoch 2/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 435s 365ms/step - accuracy: 0.5562 - loss: 1.2339 - val_accuracy: 0.6041 - val_loss: 1.0978
# Epoch 3/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 436s 360ms/step - accuracy: 0.6203 - loss: 1.0715 - val_accuracy: 0.6600 - val_loss: 0.9865
# Epoch 4/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 420s 355ms/step - accuracy: 0.6690 - loss: 0.9455 - val_accuracy: 0.6709 - val_loss: 0.9023
# Epoch 5/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 434s 349ms/step - accuracy: 0.6974 - loss: 0.8572 - val_accuracy: 0.7013 - val_loss: 0.8276
# Epoch 6/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 422s 357ms/step - accuracy: 0.7162 - loss: 0.8181 - val_accuracy: 0.6878 - val_loss: 0.8587
# Epoch 7/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 441s 373ms/step - accuracy: 0.7381 - loss: 0.7473 - val_accuracy: 0.7339 - val_loss: 0.7555
# Epoch 8/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 485s 409ms/step - accuracy: 0.7579 - loss: 0.7111 - val_accuracy: 0.7413 - val_loss: 0.7220
# Epoch 9/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 483s 409ms/step - accuracy: 0.7684 - loss: 0.6686 - val_accuracy: 0.7502 - val_loss: 0.7054
# Epoch 10/10
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 504s 411ms/step - accuracy: 0.7726 - loss: 0.6432 - val_accuracy: 0.7606 - val_loss: 0.6783

# %%
# Save model
model.save("eurosat_unet.h5")

print("Model training complete and saved as eurosat_unet.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training complete and saved as eurosat_unet.h5
